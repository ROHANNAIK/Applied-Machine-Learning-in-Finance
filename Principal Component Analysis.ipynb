# 1867        3/21/2011     114.92         3.99  17.01   40.68
# 1868        3/18/2011     114.13         3.98  18.10   42.30
# 1869        3/17/2011     114.18         3.85  18.16   44.75
# 1870        3/16/2011     110.96         3.86  18.74   45.97
#
# [1871 rows x 5 columns]

# %%
# split data table into data X and class labels y

X = data.ix[:,1:5].values
y = data.ix[:,4].values

X
# Out:
# array([[  76.77,    2.9 ,   11.33,   19.2 ],
#        [  75.55,    2.88,   11.3 ,   19.2 ],
#        [  75.67,    2.93,   11.54,   19.28],
#        ...,
#        [ 114.13,    3.98,   18.1 ,   42.3 ],
#        [ 114.18,    3.85,   18.16,   44.75],
#        [ 110.96,    3.86,   18.74,   45.97]])

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
X_std
# Out:
# array([[-0.15472106, -0.4058575 , -1.23597605, -1.10630982],
#        [-0.19667673, -0.43046329, -1.24218275, -1.10630982],
#        [-0.19254994, -0.36894881, -1.19252919, -1.09812318],
#        ...,
#        [ 1.13008529,  0.92285533,  0.16466817,  1.25758215],
#        [ 1.13180478,  0.76291767,  0.17708156,  1.50829796],
#        [ 1.02106933,  0.77522057,  0.29707767,  1.63314421]])

# %%
import numpy as np
mean_vec = np.mean(X_std, axis=0)
cov_mat = (X_std - mean_vec).T.dot((X_std - mean_vec)) / (X_std.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.00053476  0.56869761  0.33094506  0.46959295]
#  [ 0.56869761  1.00053476  0.11431428  0.20985645]
#  [ 0.33094506  0.11431428  1.00053476  0.85201429]
#  [ 0.46959295  0.20985645  0.85201429  1.00053476]]

# %%
print('NumPy covariance matrix: \n%s' %np.cov(X_std.T))
# Out:
# NumPy covariance matrix:
# [[ 1.00053476  0.56869761  0.33094506  0.46959295]
#  [ 0.56869761  1.00053476  0.11431428  0.20985645]
#  [ 0.33094506  0.11431428  1.00053476  0.85201429]
#  [ 0.46959295  0.20985645  0.85201429  1.00053476]]

# %%
cov_mat = np.cov(X_std.T)

eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.49777387 -0.42540269 -0.74121065 -0.147853  ]
#  [-0.35565649 -0.68818453  0.6323415   0.00739793]
#  [-0.535036    0.47229369  0.22085218 -0.66475519]
#  [-0.5826372   0.34981891  0.04444458  0.73224675]]
#
# Eigenvalues
# [ 2.31223649  1.16694917  0.38860089  0.13435249]

# %%
cor_mat1 = np.corrcoef(X_std.T)

eig_vals, eig_vecs = np.linalg.eig(cor_mat1)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.49777387 -0.42540269 -0.74121065 -0.147853  ]
#  [-0.35565649 -0.68818453  0.6323415   0.00739793]
#  [-0.535036    0.47229369  0.22085218 -0.66475519]
#  [-0.5826372   0.34981891  0.04444458  0.73224675]]
#
# Eigenvalues
# [ 2.31100066  1.16632546  0.3883932   0.13428068]

# %%
cor_mat2 = np.corrcoef(X.T)

eig_vals, eig_vecs = np.linalg.eig(cor_mat2)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.49777387 -0.42540269 -0.74121065 -0.147853  ]
#  [-0.35565649 -0.68818453  0.6323415   0.00739793]
#  [-0.535036    0.47229369  0.22085218 -0.66475519]
#  [-0.5826372   0.34981891  0.04444458  0.73224675]]
#
# Eigenvalues
# [ 2.31100066  1.16632546  0.3883932   0.13428068]

# %%
for ev in eig_vecs:
    np.testing.assert_array_almost_equal(1.0, np.linalg.norm(ev))
print('Everything ok!')
# Out:
# Everything ok!

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort()
eig_pairs.reverse()

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 2.31100065826
# 1.16632546291
# 0.388393195309
# 0.134280683516

# %%
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

tot = sum(eig_vals)
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)

trace1 = Bar(
        x=['PC %s' %i for i in range(1,5)],
        y=var_exp,
        showlegend=False)

trace2 = Scatter(
        x=['PC %s' %i for i in range(1,5)], 
        y=cum_var_exp,
        name='cumulative explained variance')

data = Data([trace1, trace2])

layout=Layout(
        yaxis=YAxis(title='Explained variance in percent'),
        title='Explained variance by different principal components')

fig = Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-595c60f21de1> in <module>()
# ----> 1 import plotly.plotly as py
#       2 from plotly.graph_objs import *
#       3 import plotly.tools as tls
#       4
#       5 tot = sum(eig_vals)
#
# ModuleNotFoundError: No module named 'plotly'
